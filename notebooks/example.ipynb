# %%
import pandas as pd

# 1. Sample data
data = {'habitat': ['agricultural', 'agricultural', 'wetland', 'coast']}
df = pd.DataFrame(data)

# 2. Apply One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=['habitat'])

print(df_encoded)
# Out:
#    habitat_agricultural  habitat_coast  habitat_wetland
# 0                  True          False            False
# 1                  True          False            False
# 2                 False          False             True
# 3                 False           True            False
